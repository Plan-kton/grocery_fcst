# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV file
df = pd.read_csv('fetch_fred_data.csv')
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df = df[df['date'] >= '2004-01-01']
df = df.reset_index().set_index('date').drop(columns = 'index')

df
# Out:
#                  GDP  Real Consumer Exp  Business Inv  Govt Expenditure  \
# date
# 2004-01-01  15248.68                NaN       288.018          3947.702
# 2004-02-01  15248.68                NaN       288.018          3947.702
# 2004-03-01  15248.68                NaN       288.018          3947.702
# 2004-04-01  15366.85                NaN       345.442          3982.852
# 2004-05-01  15366.85                NaN       345.442          3982.852
# ...              ...                ...           ...               ...
# 2024-11-01       NaN            16267.2           NaN               NaN
# 2024-12-01       NaN            16357.7           NaN               NaN
# 2025-01-01       NaN            16257.6           NaN               NaN
# 2025-02-01       NaN            16274.2           NaN               NaN
# 2025-03-01       NaN                NaN           NaN               NaN
#
#             Net Exports   Imports   Exports      CPI  Real Disposable Income  \
# date
# 2004-01-01     -621.175  2044.535  1339.286  186.300                 11051.2
# 2004-02-01     -621.175  2044.535  1339.286  186.700                 11071.0
# 2004-03-01     -621.175  2044.535  1339.286  187.100                 11115.6
# 2004-04-01     -670.333  2044.535  1367.358  187.400                 11153.3
# 2004-05-01     -670.333  2044.535  1367.358  188.200                 11208.9
# ...                 ...       ...       ...      ...                     ...
# 2024-11-01          NaN       NaN       NaN  316.449                 17592.4
# 2024-12-01          NaN       NaN       NaN  317.603                 17605.8
# 2025-01-01          NaN       NaN       NaN  319.086                 17661.4
# 2025-02-01          NaN       NaN       NaN  319.775                 17756.2
# 2025-03-01          NaN       NaN       NaN      NaN                     NaN
#
#             Unemployment Rate  ...  Consumer Sentiment  Avg Home Price  \
# date                           ...
# 2004-01-01                5.7  ...               103.8         140.705
# 2004-02-01                5.6  ...                94.4         142.027
# 2004-03-01                5.8  ...                95.8         144.079
# 2004-04-01                5.6  ...                94.2         146.180
# 2004-05-01                5.6  ...                90.2         148.336
# ...                       ...  ...                 ...             ...
# 2024-11-01                4.2  ...                71.8         323.784
# 2024-12-01                4.1  ...                74.0         323.328
# 2025-01-01                4.0  ...                71.7         323.538
# 2025-02-01                4.1  ...                64.7             NaN
# 2025-03-01                4.2  ...                 NaN             NaN
#
#             US Grocery Sales  CPI (Food at Home)  Restaurant Sales  \
# date
# 2004-01-01           36402.0             183.300           24839.0
# 2004-02-01           35890.0             183.700           24952.0
# 2004-03-01           36365.0             184.100           27054.0
# 2004-04-01           36312.0             184.300           26738.0
# 2004-05-01           36528.0             186.600           27839.0
# ...                      ...                 ...               ...
# 2024-11-01           75235.0             308.881           83506.0
# 2024-12-01           75998.0             309.754           86965.0
# 2025-01-01           76071.0             311.178           80656.0
# 2025-02-01           76383.0             311.203               NaN
# 2025-03-01               NaN                 NaN               NaN
#
#             Oil Prices  PPI Farm Products  PPI Food Manufacture  PPI Grocery  \
# date
# 2004-01-01   34.310000            117.400               139.300      121.300
# 2004-02-01   34.684737            120.400               140.400      125.700
# 2004-03-01   36.741304            129.100               142.400      125.200
# 2004-04-01   36.750000            129.600               146.100      123.100
# 2004-05-01   40.275000            135.100               149.100      122.200
# ...                ...                ...                   ...          ...
# 2024-11-01   69.950000            230.808               262.259      278.045
# 2024-12-01   70.118095            233.953               262.148      276.134
# 2025-01-01   75.742500            239.580               262.996      291.471
# 2025-02-01   71.533158            255.073               266.417      292.345
# 2025-03-01   68.239048                NaN                   NaN          NaN
#
#             Retail Wages
# date
# 2004-01-01           NaN
# 2004-02-01           NaN
# 2004-03-01           NaN
# 2004-04-01           NaN
# 2004-05-01           NaN
# ...                  ...
# 2024-11-01         24.93
# 2024-12-01         24.86
# 2025-01-01         24.97
# 2025-02-01         25.01
# 2025-03-01         25.18
#
# [255 rows x 26 columns]

# %%
df = df.rename(columns={
       "GDP": 'gdp',
        'Real Consumer Exp': 'cons_exp',
        'Business Inv': "bus_inv",
        'Govt Expenditure': 'govt_exp',
        'Net Exports': 'net_exp',
        'Imports': 'imports',
        'Exports': 'exports',
        'CPI': 'cpi',
        "Real Disposable Income": 'rdi',
        "Unemployment Rate": 'unrate',
        "Initial Jobless Claims": 'initial_claims',
        "Continued Jobless Claims": 'continued_claims',
        "Personal Savings": 'savings',
        "Consumer Debt % DI": 'cons_debt_di',
        "Credit Card Delinquency": 'credit_card_delinq',
        "Mortgage Delinquency": 'mortgage_delinq',
        "Consumer Sentiment": 'cons_sent',
        "Avg Home Price": 'home_price',        
        "US Grocery Sales": 'grocery_sales',  
        "CPI (Food at Home)": 'cpi_fah', 
        "Restaurant Sales": 'restaurant_sales',
        "Oil Prices": 'oil_prices',        
        "PPI Farm Products": 'ppi_farm_products',
        "PPI Food Manufacture": 'ppi_food_mfg',
        "PPI Grocery": 'ppi_grocery',
        "Retail Wages": 'wages_retail'})

# %%
# Create units
df['grocery_units'] = df['grocery_sales']/df['cpi_fah']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 255 entries, 2004-01-01 to 2025-03-01
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gdp                 250 non-null    float64
#  1   cons_exp            218 non-null    float64
#  2   bus_inv             250 non-null    float64
#  3   govt_exp            250 non-null    float64
#  4   net_exp             250 non-null    float64
#  5   imports             241 non-null    float64
#  6   exports             250 non-null    float64
#  7   cpi                 254 non-null    float64
#  8   rdi                 254 non-null    float64
#  9   unrate              255 non-null    float64
#  10  initial_claims      255 non-null    int64
#  11  continued_claims    255 non-null    int64
#  12  savings             254 non-null    float64
#  13  cons_debt_di        250 non-null    float64
#  14  credit_card_delinq  250 non-null    float64
#  15  mortgage_delinq     250 non-null    float64
#  16  cons_sent           254 non-null    float64
#  17  home_price          253 non-null    float64
#  18  grocery_sales       254 non-null    float64
#  19  cpi_fah             254 non-null    float64
#  20  restaurant_sales    253 non-null    float64
#  21  oil_prices          255 non-null    float64
#  22  ppi_farm_products   254 non-null    float64
#  23  ppi_food_mfg        254 non-null    float64
#  24  ppi_grocery         254 non-null    float64
#  25  wages_retail        229 non-null    float64
#  26  grocery_units       254 non-null    float64
# dtypes: float64(25), int64(2)
# memory usage: 55.8 KB

# %%
rdi = pd.read_excel('RDI Analysis.xlsx')
rdi = rdi.set_index('observation_date')
rdi = rdi[['RDI_adj']]
rdi = rdi.rename(columns={'RDI_adj':'rdi_adj'})
rdi = rdi[(rdi.index >= '2004-01-01') & (rdi.index <= '2025-01-31')]
rdi
# Out:
#                   rdi_adj
# observation_date
# 2004-01-01        11051.2
# 2004-02-01        11071.0
# 2004-03-01        11115.6
# 2004-04-01        11153.3
# 2004-05-01        11208.9
# ...                   ...
# 2024-09-01        17519.6
# 2024-10-01        17584.7
# 2024-11-01        17618.8
# 2024-12-01        17646.1
# 2025-01-01        17744.1
#
# [253 rows x 1 columns]

# %%
df = pd.merge(df, rdi, left_index=True, right_index=True, how='left')
df['grocery_sales_lag1'] = df['grocery_sales'].shift(1)
df
# Out:
#                  gdp  cons_exp  bus_inv  govt_exp  net_exp   imports  \
# date
# 2004-01-01  15248.68       NaN  288.018  3947.702 -621.175  2044.535
# 2004-02-01  15248.68       NaN  288.018  3947.702 -621.175  2044.535
# 2004-03-01  15248.68       NaN  288.018  3947.702 -621.175  2044.535
# 2004-04-01  15366.85       NaN  345.442  3982.852 -670.333  2044.535
# 2004-05-01  15366.85       NaN  345.442  3982.852 -670.333  2044.535
# ...              ...       ...      ...       ...      ...       ...
# 2024-11-01       NaN   16267.2      NaN       NaN      NaN       NaN
# 2024-12-01       NaN   16357.7      NaN       NaN      NaN       NaN
# 2025-01-01       NaN   16257.6      NaN       NaN      NaN       NaN
# 2025-02-01       NaN   16274.2      NaN       NaN      NaN       NaN
# 2025-03-01       NaN       NaN      NaN       NaN      NaN       NaN
#
#              exports      cpi      rdi  unrate  ...  cpi_fah  \
# date                                            ...
# 2004-01-01  1339.286  186.300  11051.2     5.7  ...  183.300
# 2004-02-01  1339.286  186.700  11071.0     5.6  ...  183.700
# 2004-03-01  1339.286  187.100  11115.6     5.8  ...  184.100
# 2004-04-01  1367.358  187.400  11153.3     5.6  ...  184.300
# 2004-05-01  1367.358  188.200  11208.9     5.6  ...  186.600
# ...              ...      ...      ...     ...  ...      ...
# 2024-11-01       NaN  316.449  17592.4     4.2  ...  308.881
# 2024-12-01       NaN  317.603  17605.8     4.1  ...  309.754
# 2025-01-01       NaN  319.086  17661.4     4.0  ...  311.178
# 2025-02-01       NaN  319.775  17756.2     4.1  ...  311.203
# 2025-03-01       NaN      NaN      NaN     4.2  ...      NaN
#
#             restaurant_sales  oil_prices  ppi_farm_products  ppi_food_mfg  \
# date
# 2004-01-01           24839.0   34.310000            117.400       139.300
# 2004-02-01           24952.0   34.684737            120.400       140.400
# 2004-03-01           27054.0   36.741304            129.100       142.400
# 2004-04-01           26738.0   36.750000            129.600       146.100
# 2004-05-01           27839.0   40.275000            135.100       149.100
# ...                      ...         ...                ...           ...
# 2024-11-01           83506.0   69.950000            230.808       262.259
# 2024-12-01           86965.0   70.118095            233.953       262.148
# 2025-01-01           80656.0   75.742500            239.580       262.996
# 2025-02-01               NaN   71.533158            255.073       266.417
# 2025-03-01               NaN   68.239048                NaN           NaN
#
#             ppi_grocery  wages_retail  grocery_units  rdi_adj  \
# date
# 2004-01-01      121.300           NaN     198.592471  11051.2
# 2004-02-01      125.700           NaN     195.372891  11071.0
# 2004-03-01      125.200           NaN     197.528517  11115.6
# 2004-04-01      123.100           NaN     197.026587  11153.3
# 2004-05-01      122.200           NaN     195.755627  11208.9
# ...                 ...           ...            ...      ...
# 2024-11-01      278.045         24.93     243.572768  17618.8
# 2024-12-01      276.134         24.86     245.349535  17646.1
# 2025-01-01      291.471         24.97     244.461369  17744.1
# 2025-02-01      292.345         25.01     245.444292      NaN
# 2025-03-01          NaN         25.18            NaN      NaN
#
#             grocery_sales_lag1
# date
# 2004-01-01                 NaN
# 2004-02-01             36402.0
# 2004-03-01             35890.0
# 2004-04-01             36365.0
# 2004-05-01             36312.0
# ...                        ...
# 2024-11-01             75403.0
# 2024-12-01             75235.0
# 2025-01-01             75998.0
# 2025-02-01             76071.0
# 2025-03-01             76383.0
#
# [255 rows x 29 columns]

# %% [markdown]
# ### Describe the Data ###

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 255 entries, 2004-01-01 to 2025-03-01
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gdp                 250 non-null    float64
#  1   cons_exp            218 non-null    float64
#  2   bus_inv             250 non-null    float64
#  3   govt_exp            250 non-null    float64
#  4   net_exp             250 non-null    float64
#  5   imports             241 non-null    float64
#  6   exports             250 non-null    float64
#  7   cpi                 254 non-null    float64
#  8   rdi                 254 non-null    float64
#  9   unrate              255 non-null    float64
#  10  initial_claims      255 non-null    int64
#  11  continued_claims    255 non-null    int64
#  12  savings             254 non-null    float64
#  13  cons_debt_di        250 non-null    float64
#  14  credit_card_delinq  250 non-null    float64
#  15  mortgage_delinq     250 non-null    float64
#  16  cons_sent           254 non-null    float64
#  17  home_price          253 non-null    float64
#  18  grocery_sales       254 non-null    float64
#  19  cpi_fah             254 non-null    float64
#  20  restaurant_sales    253 non-null    float64
#  21  oil_prices          255 non-null    float64
#  22  ppi_farm_products   254 non-null    float64
#  23  ppi_food_mfg        254 non-null    float64
#  24  ppi_grocery         254 non-null    float64
#  25  wages_retail        229 non-null    float64
#  26  grocery_units       254 non-null    float64
#  27  rdi_adj             253 non-null    float64
#  28  grocery_sales_lag1  254 non-null    float64
# dtypes: float64(27), int64(2)
# memory usage: 59.8 KB

# %%
print(df.index)
# Out:
# DatetimeIndex(['2004-01-01', '2004-02-01', '2004-03-01', '2004-04-01',
#                '2004-05-01', '2004-06-01', '2004-07-01', '2004-08-01',
#                '2004-09-01', '2004-10-01',
#                ...
#                '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01',
#                '2024-10-01', '2024-11-01', '2024-12-01', '2025-01-01',
#                '2025-02-01', '2025-03-01'],
#               dtype='datetime64[ns]', name='date', length=255, freq=None)

# %%
df.describe().T
# Out:
#                     count          mean           std           min  \
# gdp                 250.0  1.869289e+04  2.278624e+03  1.524868e+04
# cons_exp            218.0  1.303484e+04  1.608874e+03  1.106800e+04
# bus_inv             250.0  5.010356e+02  2.318096e+02 -1.471210e+02
# govt_exp            250.0  6.597726e+03  1.846293e+03  3.947702e+03
# net_exp             250.0 -5.977726e+02  2.276290e+02 -1.132084e+03
# imports             241.0  2.662404e+03  4.341877e+02  2.031762e+03
# exports             250.0  2.099427e+03  3.570417e+02  1.339286e+03
# cpi                 254.0  2.403835e+02  3.413676e+01  1.863000e+02
# rdi                 254.0  1.401597e+04  2.036385e+03  1.105120e+04
# unrate              255.0  5.785098e+00  2.084479e+00  3.400000e+00
# initial_claims      255.0  1.625843e+06  1.489609e+06  7.910000e+05
# continued_claims    255.0  1.345931e+07  1.058681e+07  5.465000e+06
# savings             254.0  8.491819e+02  6.911563e+02  1.289000e+02
# cons_debt_di        250.0  5.868489e+00  7.232003e-01  4.305925e+00
# credit_card_delinq  250.0  3.217880e+00  1.222611e+00  1.530000e+00
# mortgage_delinq     250.0  4.746120e+00  3.300703e+00  1.410000e+00
# cons_sent           254.0  8.074055e+01  1.291760e+01  5.000000e+01
# home_price          253.0  1.960504e+02  5.521561e+01  1.339910e+02
# grocery_sales       254.0  5.231067e+04  1.169290e+04  3.589000e+04
# cpi_fah             254.0  2.365460e+02  3.323358e+01  1.833000e+02
# restaurant_sales    253.0  4.651515e+04  1.702542e+04  2.483900e+04
# oil_prices          255.0  7.039149e+01  2.175238e+01  1.654762e+01
# ppi_farm_products   254.0  1.717793e+02  3.684790e+01  1.098000e+02
# ppi_food_mfg        254.0  1.957319e+02  3.300856e+01  1.393000e+02
# ppi_grocery         254.0  1.839566e+02  4.351648e+01  1.210000e+02
# wages_retail        229.0  1.843852e+01  3.119366e+00  1.508000e+01
# grocery_units       254.0  2.189371e+02  2.054310e+01  1.922587e+02
# rdi_adj             253.0  1.402702e+04  2.055146e+03  1.105120e+04
# grocery_sales_lag1  254.0  5.231067e+04  1.169290e+04  3.589000e+04
#
#                              25%           50%           75%           max
# gdp                 1.675977e+04  1.818591e+04  2.054879e+04  2.354235e+04
# cons_exp            1.153705e+04  1.276625e+04  1.406695e+04  1.635770e+04
# bus_inv             3.932990e+02  5.039140e+02  6.384730e+02  9.433440e+02
# govt_exp            5.560375e+03  5.972949e+03  7.393724e+03  1.118667e+04
# net_exp            -7.138420e+02 -5.579370e+02 -3.883352e+02 -2.755520e+02
# imports             2.325403e+03  2.623351e+03  3.049962e+03  3.640014e+03
# exports             1.816114e+03  2.230209e+03  2.381788e+03  2.638199e+03
# cpi                 2.160230e+02  2.362370e+02  2.563315e+02  3.197750e+02
# rdi                 1.227495e+04  1.346610e+04  1.570305e+04  2.044580e+04
# unrate              4.200000e+00  5.000000e+00  7.200000e+00  1.480000e+01
# initial_claims      1.063500e+06  1.331000e+06  1.681000e+06  1.865300e+07
# continued_claims    8.472000e+06  1.088400e+07  1.475550e+07  1.016320e+08
# savings             5.712500e+02  7.447500e+02  9.451250e+02  5.981600e+03
# cons_debt_di        5.434135e+00  5.712078e+00  6.373640e+00  7.306876e+00
# credit_card_delinq  2.332500e+00  2.710000e+00  4.010000e+00  6.770000e+00
# mortgage_delinq     1.920000e+00  3.220000e+00  7.685000e+00  1.149000e+01
# cons_sent           7.065000e+01  8.140000e+01  9.260000e+01  1.038000e+02
# home_price          1.560710e+02  1.796750e+02  2.119520e+02  3.256770e+02
# grocery_sales       4.270900e+04  5.043800e+04  5.810525e+04  7.638300e+04
# cpi_fah             2.151382e+02  2.377690e+02  2.431218e+02  3.112030e+02
# restaurant_sales    3.293000e+04  4.146900e+04  5.506900e+04  8.962400e+04
# oil_prices          5.312976e+01  7.023211e+01  8.606054e+01  1.338800e+02
# ppi_farm_products   1.456750e+02  1.660500e+02  1.955500e+02  2.638170e+02
# ppi_food_mfg        1.712500e+02  1.978500e+02  2.046000e+02  2.664170e+02
# ppi_grocery         1.499250e+02  1.774500e+02  2.064250e+02  2.923450e+02
# wages_retail        1.565000e+01  1.765000e+01  2.095000e+01  2.518000e+01
# grocery_units       2.021149e+02  2.097885e+02  2.399253e+02  3.027055e+02
# rdi_adj             1.227320e+04  1.344590e+04  1.569750e+04  1.824775e+04
# grocery_sales_lag1  4.270900e+04  5.043800e+04  5.810525e+04  7.638300e+04

# %% [markdown]
# ### Missing Values, Duplicates, and Outliers ###

# %%
# Count total missing values per column
missing_counts = df.isna().sum()

# Show only columns with missing values
missing_counts = missing_counts[missing_counts > 0]

missing_counts
# Out:
# gdp                    5
# cons_exp              37
# bus_inv                5
# govt_exp               5
# net_exp                5
# imports               14
# exports                5
# cpi                    1
# rdi                    1
# savings                1
# cons_debt_di           5
# credit_card_delinq     5
# mortgage_delinq        5
# cons_sent              1
# home_price             2
# grocery_sales          1
# cpi_fah                1
# restaurant_sales       2
# ppi_farm_products      1
# ppi_food_mfg           1
# ppi_grocery            1
# wages_retail          26
# grocery_units          1
# rdi_adj                2
# grocery_sales_lag1     1
# dtype: int64

# %%
#fill in missing values
df = df.ffill()
df['grocery_sales_lag1'] = df['grocery_sales_lag1'].bfill()

# %%
# Count total missing values per column
missing_counts = df.isna().sum()

# Show only columns with missing values
missing_counts = missing_counts[missing_counts > 0]

missing_counts
# Out:
# cons_exp        36
# wages_retail    26
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Identify outliers using IQR
cols = df.columns.tolist()

Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)

IQR = Q3 - Q1

lower_whisker = Q1 - 1.5 * IQR
upper_whisker = Q3 + 1.5 * IQR

IQR_df = pd.DataFrame(
    {'Column': Q1.index,                        # Column names
    'Q1 (25th percentile)': Q1.values,          # Q1 values
    'Q3 (75th percentile)': Q3.values,          # Q3 values
    'IQR': IQR.values,                          # Interquartile range
    'Lower Whisker': lower_whisker.values,      # Lower whisker
    'Upper Whisker': upper_whisker.values})      # Upper whisker

#This provides the percent of values above or below the whiskers
((df[cols] < lower_whisker) | (df[cols] > upper_whisker)).sum() / len(df) * 100
# Out:
# gdp                    0.000000
# cons_exp               0.000000
# bus_inv                5.882353
# govt_exp               5.882353
# net_exp                0.000000
# imports                0.000000
# exports                0.000000
# cpi                    1.568627
# rdi                    0.000000
# unrate                 0.784314
# initial_claims         7.058824
# continued_claims       6.274510
# savings                7.058824
# cons_debt_di           0.000000
# credit_card_delinq     3.529412
# mortgage_delinq        0.000000
# cons_sent              0.000000
# home_price            12.941176
# grocery_sales          0.000000
# cpi_fah               13.725490
# restaurant_sales       0.784314
# oil_prices             0.000000
# ppi_farm_products      0.000000
# ppi_food_mfg           8.235294
# ppi_grocery            0.000000
# wages_retail           0.000000
# grocery_units          0.392157
# rdi_adj                0.000000
# grocery_sales_lag1     0.000000
# dtype: float64

# %% [markdown]
# ### Visualizations ###

# %%
# Select the variables to plot (excluding 'date')
var_list = df.columns.tolist()

# Create a grid of subplots (2 columns × enough rows for all variables)
num_vars = len(var_list)
rows = (num_vars // 2) + (num_vars % 2)  # Ensures enough rows for all variables

fig, axes = plt.subplots(nrows=rows, ncols=2, figsize=(15, 5 * rows))  # Dynamically sized

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through each variable and plot
for i, col in enumerate(var_list):
    ax = axes[i]  # Select the subplot
    ax.plot(df.index, df[col], label=col, linewidth=2)
    
    # Customize the subplot
    ax.set_title(col, fontsize=12)
    ax.set_xlabel("Date", fontsize=10)
    ax.set_ylabel("Value", fontsize=10)
    ax.grid(True)
    ax.legend()

# Adjust layout for readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Select independent variables (excluding index)
var_list = df.columns.tolist()  # Since 'date' is index, it's not included

# Create a grid of subplots (2 columns × enough rows for all variables)
num_vars = len(var_list)
rows = (num_vars // 2) + (num_vars % 2)  # Ensures enough rows for all variables

fig, axes = plt.subplots(nrows=rows, ncols=2, figsize=(15, 5 * rows))  # Dynamically sized

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through each variable and create scatter plots
for i, col in enumerate(var_list):
    ax = axes[i]
    ax.scatter(df[col], df['grocery_sales'], color='green', alpha=0.6)
    ax.set_xlabel(col, fontsize=10)
    ax.set_ylabel('Grocery Sales', fontsize=10)
    ax.set_title(f'Scatter Plot: {col} vs Grocery Sales')

# Hide empty subplots if `var_list` has an odd number of elements
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout and show all plots
plt.tight_layout()
plt.show()

# %%
# Compute the correlation matrix
df_corr = df.select_dtypes(include=['number']).corr()

plt.figure(figsize=(14, 6))
sns.heatmap(df_corr, annot=True, cbar=False, cmap="coolwarm")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 255 entries, 2004-01-01 to 2025-03-01
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gdp                 255 non-null    float64
#  1   cons_exp            219 non-null    float64
#  2   bus_inv             255 non-null    float64
#  3   govt_exp            255 non-null    float64
#  4   net_exp             255 non-null    float64
#  5   imports             255 non-null    float64
#  6   exports             255 non-null    float64
#  7   cpi                 255 non-null    float64
#  8   rdi                 255 non-null    float64
#  9   unrate              255 non-null    float64
#  10  initial_claims      255 non-null    int64
#  11  continued_claims    255 non-null    int64
#  12  savings             255 non-null    float64
#  13  cons_debt_di        255 non-null    float64
#  14  credit_card_delinq  255 non-null    float64
#  15  mortgage_delinq     255 non-null    float64
#  16  cons_sent           255 non-null    float64
#  17  home_price          255 non-null    float64
#  18  grocery_sales       255 non-null    float64
#  19  cpi_fah             255 non-null    float64
#  20  restaurant_sales    255 non-null    float64
#  21  oil_prices          255 non-null    float64
#  22  ppi_farm_products   255 non-null    float64
#  23  ppi_food_mfg        255 non-null    float64
#  24  ppi_grocery         255 non-null    float64
#  25  wages_retail        229 non-null    float64
#  26  grocery_units       255 non-null    float64
#  27  rdi_adj             255 non-null    float64
#  28  grocery_sales_lag1  255 non-null    float64
# dtypes: float64(27), int64(2)
# memory usage: 59.8 KB

# %% [markdown]
# ### Feature Creation ###

# %%
#feature creation

# Create first difference variables (applies to all numeric columns)
df_diff = df.diff().add_suffix('_diff')
df_diff = df_diff.bfill()

# Create YOY variables (applies to all numeric columns)
df_yoy = df.pct_change(periods=12, fill_method=None).add_suffix('_yoy') * 100  # Converts to percentage

# Create dummy1 for dates between 2/29/2020 and 4/30/2020. A boolean consition with a .astype(int) will return a 1 for True and 0 for false
df['covid1'] = ((df.index >= '2020-02-01') & (df.index <= '2020-04-01')).astype(int)

# Create dummy2 for dates between 5/31/2020 and 10/31/2020
df['covid2'] = ((df.index >= '2020-05-01') & (df.index <= '2020-10-01')).astype(int)

# reduce grocery sales for March 2020
df.loc[df.index == '2020-03-01', 'grocery_sales'] = 61000

# %%
df = pd.concat([df, df_diff, df_yoy], axis=1)

# %%
for col in df.columns:
    print(col)
# Out:
# gdp
# cons_exp
# bus_inv
# govt_exp
# net_exp
# imports
# exports
# cpi
# rdi
# unrate
# initial_claims
# continued_claims
# savings
# cons_debt_di
# credit_card_delinq
# mortgage_delinq
# cons_sent
# home_price
# grocery_sales
# cpi_fah
# restaurant_sales
# oil_prices
# ppi_farm_products
# ppi_food_mfg
# ppi_grocery
# wages_retail
# grocery_units
# rdi_adj
# grocery_sales_lag1
# covid1
# covid2
# gdp_diff
# cons_exp_diff
# bus_inv_diff
# govt_exp_diff
# net_exp_diff
# imports_diff
# exports_diff
# cpi_diff
# rdi_diff
# unrate_diff
# initial_claims_diff
# continued_claims_diff
# savings_diff
# cons_debt_di_diff
# credit_card_delinq_diff
# mortgage_delinq_diff
# cons_sent_diff
# home_price_diff
# grocery_sales_diff
# cpi_fah_diff
# restaurant_sales_diff
# oil_prices_diff
# ppi_farm_products_diff
# ppi_food_mfg_diff
# ppi_grocery_diff
# wages_retail_diff
# grocery_units_diff
# rdi_adj_diff
# grocery_sales_lag1_diff
# gdp_yoy
# cons_exp_yoy
# bus_inv_yoy
# govt_exp_yoy
# net_exp_yoy
# imports_yoy
# exports_yoy
# cpi_yoy
# rdi_yoy
# unrate_yoy
# initial_claims_yoy
# continued_claims_yoy
# savings_yoy
# cons_debt_di_yoy
# credit_card_delinq_yoy
# mortgage_delinq_yoy
# cons_sent_yoy
# home_price_yoy
# grocery_sales_yoy
# cpi_fah_yoy
# restaurant_sales_yoy
# oil_prices_yoy
# ppi_farm_products_yoy
# ppi_food_mfg_yoy
# ppi_grocery_yoy
# wages_retail_yoy
# grocery_units_yoy
# rdi_adj_yoy
# grocery_sales_lag1_yoy

# %%
df.to_csv('grocery_dataset_eda.csv', index = True)
